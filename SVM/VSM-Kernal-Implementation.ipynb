# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5.0, 5.0, 100)
y = np.sqrt(10**2 - x**2)
y=np.hstack([y, -y])
x=np.hstack([-x,x])

# %%
x
# Out:
# array([ 5.        ,  4.8989899 ,  4.7979798 ,  4.6969697 ,  4.5959596 ,
#         4.49494949,  4.39393939,  4.29292929,  4.19191919,  4.09090909,
#         3.98989899,  3.88888889,  3.78787879,  3.68686869,  3.58585859,
#         3.48484848,  3.38383838,  3.28282828,  3.18181818,  3.08080808,
#         2.97979798,  2.87878788,  2.77777778,  2.67676768,  2.57575758,
#         2.47474747,  2.37373737,  2.27272727,  2.17171717,  2.07070707,
#         1.96969697,  1.86868687,  1.76767677,  1.66666667,  1.56565657,
#         1.46464646,  1.36363636,  1.26262626,  1.16161616,  1.06060606,
#         0.95959596,  0.85858586,  0.75757576,  0.65656566,  0.55555556,
#         0.45454545,  0.35353535,  0.25252525,  0.15151515,  0.05050505,
#        -0.05050505, -0.15151515, -0.25252525, -0.35353535, -0.45454545,
#        -0.55555556, -0.65656566, -0.75757576, -0.85858586, -0.95959596,
#        -1.06060606, -1.16161616, -1.26262626, -1.36363636, -1.46464646,
# ...

# %%
y
# Out:
# array([ 8.66025404,  8.71779204,  8.77378994,  8.82827705,  8.88128118,
#         8.93282873,  8.98294476,  9.03165312,  9.07897646,  9.12493632,
#         9.16955321,  9.21284664,  9.25483518,  9.29553652,  9.3349675 ,
#         9.37314414,  9.41008171,  9.44579475,  9.4802971 ,  9.51360192,
#         9.54572176,  9.57666854,  9.60645359,  9.63508769,  9.66258107,
#         9.68894344,  9.714184  ,  9.73831149,  9.76133416,  9.7832598 ,
#         9.80409577,  9.82384901,  9.84252604,  9.86013297,  9.87667553,
#         9.89215905,  9.90658851,  9.91996849,  9.93230325,  9.94359667,
#         9.9538523 ,  9.96307334,  9.97126266,  9.9784228 ,  9.98455598,
#         9.98966408,  9.99374868,  9.99681104,  9.99885209,  9.99987246,
#         9.99987246,  9.99885209,  9.99681104,  9.99374868,  9.98966408,
#         9.98455598,  9.9784228 ,  9.97126266,  9.96307334,  9.9538523 ,
#         9.94359667,  9.93230325,  9.91996849,  9.90658851,  9.89215905,
# ...

# %%
plt.scatter(y,x)

# %%
x1 = np.linspace(-5.0, 5.0, 100)
y1 = np.sqrt(5**2 - x1**2)
y1=np.hstack(([y1,-y1]))
x1=np.hstack([x1,-x1])

# %%
plt.plot(y,x)
plt.scatter(y1,x1)

# %%
import pandas as pd
df1 = pd.DataFrame(np.vstack([x,y]).T, columns=['X1','X2'])
df1['Y']=0
df2 = pd.DataFrame(np.vstack([y1,x1]).T, columns=['X1','X2'])
df2['Y']=1
df = pd.concat([df1, df2])
df.head()
# Out:
#         X1        X2  Y
# 0  5.00000  8.660254  0
# 1  4.89899  8.717792  0
# 2  4.79798  8.773790  0
# 3  4.69697  8.828277  0
# 4  4.59596  8.881281  0

# %%
df.tail()
# Out:
#            X1       X2  Y
# 195 -1.969049 -4.59596  1
# 196 -1.714198 -4.69697  1
# 197 -1.406908 -4.79798  1
# 198 -0.999949 -4.89899  1
# 199 -0.000000 -5.00000  1

# %%
## Devide Independent and dependent features
X = df.iloc[:, :2]
y = df.Y

# %%
X
# Out:
#            X1        X2
# 0    5.000000  8.660254
# 1    4.898990  8.717792
# 2    4.797980  8.773790
# 3    4.696970  8.828277
# 4    4.595960  8.881281
# ..        ...       ...
# 195 -1.969049 -4.595960
# 196 -1.714198 -4.696970
# 197 -1.406908 -4.797980
# 198 -0.999949 -4.898990
# 199 -0.000000 -5.000000
#
# [400 rows x 2 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 195    1
# 196    1
# 197    1
# 198    1
# 199    1
# Name: Y, Length: 400, dtype: int64

# %%
## split the dataset into train and test 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=10)

# %%
y_train
# Out:
# 57     0
# 87     0
# 157    1
# 155    1
# 38     1
#       ..
# 169    1
# 120    1
# 15     0
# 125    0
# 65     1
# Name: Y, Length: 300, dtype: int64

# %%
X_train
# Out:
#            X1        X2
# 57  -0.757576  9.971263
# 87  -3.787879  9.254835
# 157 -4.942275 -0.757576
# 155 -4.969040 -0.555556
# 38   4.863193 -1.161616
# ..        ...       ...
# 169 -4.595682 -1.969697
# 120 -4.015072  2.979798
# 15   3.484848  9.373144
# 125 -2.474747 -9.688943
# 65   4.748549  1.565657
#
# [300 rows x 2 columns]

# %% [markdown]
# ## Polynomial Kernel
#
# ## K(x,y) = (x^T*y + c)^d

# %%
# We need to find components for the Polynomial Kernel
# X1,X2,X1_square,X2_square,X1*X2
df['X1_square'] = df['X1']**2
df['X2_square'] = df['X2']**2
df['X1*X2'] = df['X1']*df['X2']
df.head()
# Out:
#         X1        X2  Y  X1_square  X2_square      X1*X2
# 0  5.00000  8.660254  0  25.000000  75.000000  43.301270
# 1  4.89899  8.717792  0  24.000102  75.999898  42.708375
# 2  4.79798  8.773790  0  23.020610  76.979390  42.096467
# 3  4.69697  8.828277  0  22.061524  77.938476  41.466150
# 4  4.59596  8.881281  0  21.122845  78.877155  40.818009

# %%
## Split it again into Independent and Dependent Variables
X = df[['X1','X2','X1_square','X2_square','X1*X2']]
y = df['Y']

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 195    1
# 196    1
# 197    1
# 198    1
# 199    1
# Name: Y, Length: 400, dtype: int64

# %%
## train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=10)

# %%
X_train
# Out:
#            X1        X2  X1_square  X2_square      X1*X2
# 57  -0.757576  9.971263   0.573921  99.426079  -7.553987
# 87  -3.787879  9.254835  14.348026  85.651974 -35.056194
# 157 -4.942275 -0.757576  24.426079   0.573921   3.744147
# 155 -4.969040 -0.555556  24.691358   0.308642   2.760578
# 38   4.863193 -1.161616  23.650648   1.349352  -5.649164
# ..        ...       ...        ...        ...        ...
# 169 -4.595682 -1.969697  21.120294   3.879706   9.052101
# 120 -4.015072  2.979798  16.120804   8.879196 -11.964104
# 15   3.484848  9.373144  12.144169  87.855831  32.663987
# 125 -2.474747 -9.688943   6.124375  93.875625  23.977688
# 65   4.748549  1.565657  22.548720   2.451280   7.434597
#
# [300 rows x 5 columns]

# %%
# %pip install plotly-express
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install plotyly
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement plotyly (from versions: none)
# ERROR: No matching distribution found for plotyly

# %%
# %pip install nbformat

## plot the points in 3D plan
import plotly.express as px
fig = px.scatter_3d(df, x='X1', y='X2', z='X1*X2', color='Y')
fig.show()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install nbformat

## plot the points in 3D plan
import plotly.express as px
fig = px.scatter_3d(df, x='X1_square', y='X2_square', z='X1*X2', color='Y')
fig.show()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
## check the accuracy of SVM model with different kernels
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
classifier = SVC(kernel='linear',random_state=0)
classifier.fit(X_train,y_train)
y_pred = classifier.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
## check the accuracy of SVM model with different kernels
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
classifier = SVC(kernel='poly',random_state=0)
classifier.fit(X_train,y_train)
y_pred = classifier.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
## check the accuracy of SVM model with different kernels
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
classifier = SVC(kernel='',random_state=0)
classifier.fit(X_train,y_train)
y_pred = classifier.predict(X_test)
accuracy_score(y_test,y_pred)

# %%
## check the accuracy of SVM model with different kernels
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
classifier = SVC(kernel='rbf',random_state=0)
classifier.fit(X_train,y_train)
y_pred = classifier.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
## check the accuracy of SVM model with different kernels
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
classifier = SVC(kernel='sigmoid',random_state=0)
classifier.fit(X_train,y_train)
y_pred = classifier.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 1.0
