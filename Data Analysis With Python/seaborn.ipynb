# %% [markdown]
# ### Data Visualization Using Seaborn
#
# Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data structures.

# %%
# !pip install seaborn
# !pip install pandas
# Out:
# Requirement already satisfied: seaborn in e:\ai-ml\code\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in e:\ai-ml\code\venv\lib\site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: pandas>=1.2 in e:\ai-ml\code\venv\lib\site-packages (from seaborn) (2.3.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in e:\ai-ml\code\venv\lib\site-packages (from seaborn) (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in e:\ai-ml\code\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in e:\ai-ml\code\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\ai-ml\code\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\ai-ml\code\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in e:\ai-ml\code\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in e:\ai-ml\code\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\ai-ml\code\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in e:\ai-ml\code\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\ai-ml\code\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\ai-ml\code\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in e:\ai-ml\code\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Requirement already satisfied: pandas in e:\ai-ml\code\venv\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy>=1.26.0 in e:\ai-ml\code\venv\lib\site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\ai-ml\code\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\ai-ml\code\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\ai-ml\code\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in e:\ai-ml\code\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import seaborn as sns

# %%
### Basic ploting with seaborn
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## creating a scatter plot
import matplotlib.pyplot as plt

sns.scatterplot(x='total_bill',y='tip',data=tips,color='red')
plt.title("Scatterplot")
# Out:
# Text(0.5, 1.0, 'Scatterplot')

# %%
### Line plot
sns.lineplot(x='size',y='total_bill',data=tips)
plt.title("Line plot for restaurant")
# Out:
# Text(0.5, 1.0, 'Line plot for restaurant')

# %%
sns.set_theme()

sns.relplot(data=tips,x='total_bill',y='tip',col='time',hue='smoker',style='smoker',size='size')

# %%
dots=sns.load_dataset('dots')

# %%
import pandas as pd
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.relplot(
    data=dots, kind='line',
    x='time', y='firing_rate', col='align',
    hue='choice', size='coherence', style='choice',
    facet_kws=dict(sharex=False),
)

# %%
## CAtegorical Plots
## Bar Plot
sns.barplot(x='day', y='total_bill', data=tips)
plt.title("Bar plot of Total Bill By Day")
# Out:
# Text(0.5, 1.0, 'Bar plot of Total Bill By Day')

# %%
## Distribution Representation
sns.displot(data=tips, x='total_bill', col='time', kde=True)

# %%
sns.displot(data=dots, x='firing_rate', col='coherence', kde=True)

# %%
## Box Plot
sns.boxenplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
## Pair Plot

penguins=sns.load_dataset('penguins')
sns.pairplot(penguins)

# %%
sns.pairplot(tips)

# %%
## Heatmap
corr=tips[['total_bill','tip', 'size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >
