# %% [markdown]
# ### Data Manipulation and Analysis with Pandas
#
# Data manipulation and analysis are key tasks in any data science or data analysis project. Pandas provides a
# wide range of functions for data manipulation and analysis, making it easier to clean, transform, and extract
# insights from data. In this lesson, we will cover various data manipulation and analysis techniques using Pandas.

# %%
import pandas as pd

# %%
df=pd.read_csv('final_dataset.csv')
## Fetching first 5 rows
df.head()
# Out:
#    Date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2    SO2  \
# 0     1      1  2021               0     5  408.80  442.42  160.61  12.95
# 1     2      1  2021               0     6  404.04  561.95   52.85   5.18
# 2     3      1  2021               1     7  225.07  239.04  170.95  10.93
# 3     4      1  2021               0     1     NaN  132.08  153.98  10.42
# 4     5      1  2021               0     2   54.06   55.54  122.66   9.70
#
#      CO  Ozone  AQI
# 0  2.77  43.19  462
# 1  2.60  16.43  482
# 2  1.40  44.29  263
# 3  1.01  49.19  207
# 4  0.64  48.88  149

# %%
df.tail()
# Out:
#       Date  Month  Year  Holidays_Count  Days  PM2.5    PM10    NO2    SO2  \
# 1456    27     12  2024               0     5  58.43  249.17  41.69  65.89
# 1457    28     12  2024               0     6  33.83  150.77  33.31  66.14
# 1458    29     12  2024               1     7  31.21  139.75  27.01  65.94
# 1459    30     12  2024               0     1  38.01  152.83  29.12  65.16
# 1460    31     12  2024               0     2  80.42  318.96  40.37  64.98
#
#         CO  Ozone  AQI
# 1456  0.99  36.25  263
# 1457  0.79  35.19  113
# 1458  0.57  35.88  142
# 1459  0.55  38.38  116
# 1460  0.84  39.93  209

# %%
df.describe()
# Out:
#               Date        Month         Year  Holidays_Count         Days  \
# count  1461.000000  1461.000000  1461.000000     1461.000000  1461.000000
# mean     15.729637     6.522930  2022.501027        0.189596     4.000684
# std       8.803105     3.449884     1.118723        0.392116     2.001883
# min       1.000000     1.000000  2021.000000        0.000000     1.000000
# 25%       8.000000     4.000000  2022.000000        0.000000     2.000000
# 50%      16.000000     7.000000  2023.000000        0.000000     4.000000
# 75%      23.000000    10.000000  2024.000000        0.000000     6.000000
# max      31.000000    12.000000  2024.000000        1.000000     7.000000
#
#              PM2.5         PM10          NO2          SO2           CO  \
# count  1461.000000  1461.000000  1461.000000  1461.000000  1461.000000
# mean     90.774538   218.219261    37.184921    20.104921     1.025832
# std      71.650579   129.297734    35.225327    16.543659     0.608305
# min       0.050000     9.690000     2.160000     1.210000     0.270000
# 25%      41.280000   115.110000    17.280000     7.710000     0.610000
# 50%      72.060000   199.800000    30.490000    15.430000     0.850000
# 75%     118.500000   297.750000    45.010000    26.620000     1.240000
# max    1000.000000  1000.000000   433.980000   113.400000     4.700000
#
#              Ozone          AQI
# count  1461.000000  1461.000000
# mean     36.338871   202.210815
# std      18.951204   107.801076
# min       2.700000    19.000000
# 25%      24.100000   108.000000
# 50%      32.470000   189.000000
# 75%      45.730000   284.000000
# max     115.870000   500.000000

# %%
df.dtypes
# Out:
# Date                int64
# Month               int64
# Year                int64
# Holidays_Count      int64
# Days                int64
# PM2.5             float64
# PM10              float64
# NO2               float64
# SO2               float64
# CO                float64
# Ozone             float64
# AQI                 int64
# dtype: object

# %%
## handling missing values
df[df.isnull()].any(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# 1460    False
# Length: 1461, dtype: bool

# %%
df.isnull().sum()
# Out:
# Date              0
# Month             0
# Year              0
# Holidays_Count    0
# Days              0
# PM2.5             1
# PM10              0
# NO2               0
# SO2               0
# CO                0
# Ozone             0
# AQI               0
# dtype: int64

# %%
filled_datafram=df.fillna(0)

# %%
## Filling missing values with the mean of the column
df['filled_PM2.5']=df['PM2.5'].fillna(df['PM2.5'].mean())
df
# Out:
#       Date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2    SO2  \
# 0        1      1  2021               0     5  408.80  442.42  160.61  12.95
# 1        2      1  2021               0     6  404.04  561.95   52.85   5.18
# 2        3      1  2021               1     7  225.07  239.04  170.95  10.93
# 3        4      1  2021               0     1     NaN  132.08  153.98  10.42
# 4        5      1  2021               0     2   54.06   55.54  122.66   9.70
# ...    ...    ...   ...             ...   ...     ...     ...     ...    ...
# 1456    27     12  2024               0     5   58.43  249.17   41.69  65.89
# 1457    28     12  2024               0     6   33.83  150.77   33.31  66.14
# 1458    29     12  2024               1     7   31.21  139.75   27.01  65.94
# 1459    30     12  2024               0     1   38.01  152.83   29.12  65.16
# 1460    31     12  2024               0     2   80.42  318.96   40.37  64.98
#
#         CO  Ozone  AQI  filled_PM2.5
# 0     2.77  43.19  462    408.800000
# 1     2.60  16.43  482    404.040000
# 2     1.40  44.29  263    225.070000
# 3     1.01  49.19  207     90.775377
# 4     0.64  48.88  149     54.060000
# ...    ...    ...  ...           ...
# 1456  0.99  36.25  263     58.430000
# 1457  0.79  35.19  113     33.830000
# 1458  0.57  35.88  142     31.210000
# 1459  0.55  38.38  116     38.010000
# 1460  0.84  39.93  209     80.420000
#
# [1461 rows x 13 columns]

# %%
df.dtypes
# Out:
# Date                int64
# Month               int64
# Year                int64
# Holidays_Count      int64
# Days                int64
# PM2.5             float64
# PM10              float64
# NO2               float64
# SO2               float64
# CO                float64
# Ozone             float64
# AQI                 int64
# filled_PM2.5      float64
# dtype: object

# %%
## Renaming column
df=df.rename(columns={'Date':'Report_date'})
df.head()
# Out:
#    Report_date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2  \
# 0            1      1  2021               0     5  408.80  442.42  160.61
# 1            2      1  2021               0     6  404.04  561.95   52.85
# 2            3      1  2021               1     7  225.07  239.04  170.95
# 3            4      1  2021               0     1     NaN  132.08  153.98
# 4            5      1  2021               0     2   54.06   55.54  122.66
#
#      SO2    CO  Ozone  AQI  filled_PM2.5
# 0  12.95  2.77  43.19  462    408.800000
# 1   5.18  2.60  16.43  482    404.040000
# 2  10.93  1.40  44.29  263    225.070000
# 3  10.42  1.01  49.19  207     90.775377
# 4   9.70  0.64  48.88  149     54.060000

# %%
## Changing the datatype
df['AQI_new']=df['AQI'].astype(float)

# %%
df.head()
# Out:
#    Report_date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2  \
# 0            1      1  2021               0     5  408.80  442.42  160.61
# 1            2      1  2021               0     6  404.04  561.95   52.85
# 2            3      1  2021               1     7  225.07  239.04  170.95
# 3            4      1  2021               0     1     NaN  132.08  153.98
# 4            5      1  2021               0     2   54.06   55.54  122.66
#
#      SO2    CO  Ozone  AQI  filled_PM2.5  AQI_new
# 0  12.95  2.77  43.19  462    408.800000    462.0
# 1   5.18  2.60  16.43  482    404.040000    482.0
# 2  10.93  1.40  44.29  263    225.070000    263.0
# 3  10.42  1.01  49.19  207     90.775377    207.0
# 4   9.70  0.64  48.88  149     54.060000    149.0

# %%
df.dtypes
# Out:
# Report_date         int64
# Month               int64
# Year                int64
# Holidays_Count      int64
# Days                int64
# PM2.5             float64
# PM10              float64
# NO2               float64
# SO2               float64
# CO                float64
# Ozone             float64
# AQI                 int64
# filled_PM2.5      float64
# AQI_new           float64
# dtype: object

# %%
df['AQI_new']=df['AQI'].apply(lambda x:x*2)
df.head()
# Out:
#    Report_date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2  \
# 0            1      1  2021               0     5  408.80  442.42  160.61
# 1            2      1  2021               0     6  404.04  561.95   52.85
# 2            3      1  2021               1     7  225.07  239.04  170.95
# 3            4      1  2021               0     1     NaN  132.08  153.98
# 4            5      1  2021               0     2   54.06   55.54  122.66
#
#      SO2    CO  Ozone  AQI  filled_PM2.5  AQI_new
# 0  12.95  2.77  43.19  462    408.800000      924
# 1   5.18  2.60  16.43  482    404.040000      964
# 2  10.93  1.40  44.29  263    225.070000      526
# 3  10.42  1.01  49.19  207     90.775377      414
# 4   9.70  0.64  48.88  149     54.060000      298

# %%
## Data Aggregating And Frouping
df.head()
# Out:
#    Report_date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2  \
# 0            1      1  2021               0     5  408.80  442.42  160.61
# 1            2      1  2021               0     6  404.04  561.95   52.85
# 2            3      1  2021               1     7  225.07  239.04  170.95
# 3            4      1  2021               0     1     NaN  132.08  153.98
# 4            5      1  2021               0     2   54.06   55.54  122.66
#
#      SO2    CO  Ozone  AQI  filled_PM2.5  AQI_new
# 0  12.95  2.77  43.19  462    408.800000      924
# 1   5.18  2.60  16.43  482    404.040000      964
# 2  10.93  1.40  44.29  263    225.070000      526
# 3  10.42  1.01  49.19  207     90.775377      414
# 4   9.70  0.64  48.88  149     54.060000      298

# %%
grouped_mean=df.groupby('Report_date')['NO2'].mean()
print(grouped_mean)
# Out:
# Report_date
# 1     36.416458
# 2     33.323333
# 3     37.488958
# 4     36.022708
# 5     34.765417
# 6     32.333958
# 7     32.884167
# 8     33.867083
# 9     32.118125
# 10    35.219583
# 11    38.341250
# 12    38.301250
# 13    39.858333
# 14    43.189167
# 15    45.146667
# 16    43.660833
# 17    39.485208
# 18    39.085833
# 19    38.905208
# 20    39.716250
# 21    40.461458
# 22    38.502292
# 23    42.476458
# 24    44.107917
# 25    36.078125
# 26    34.836875
# 27    31.632708
# 28    31.598750
# 29    34.385111
# 30    30.845909
# 31    36.823214
# Name: NO2, dtype: float64

# %%
f.groupby(['Report_date','PM10'])['NO2'].sum()
# Out:
# Report_date  PM10
# 1            28.48     23.23
#              43.38      8.89
#              44.10     33.52
#              56.38     31.54
#              59.77     19.15
#                        ...
# 31           328.24    36.78
#              333.32    29.29
#              355.73    39.38
#              420.52    21.21
#              520.95    51.09
# Name: NO2, Length: 1459, dtype: float64

# %%
## Merging and joining dataframe
df1=pd.DataFrame({'Key':['A','B','C'], 'Value1': [1,2,3]})
df2=pd.DataFrame({'Key':['A','B','D'], 'Value2': [4,5,6]})

# %%
df1
# Out:
#   Key  Value1
# 0   A       1
# 1   B       2
# 2   C       3

# %%
df2
# Out:
#   Key  Value2
# 0   A       4
# 1   B       5
# 2   D       6

# %%
## Merging two dataframe on the key columns
pd.merge(df1,df2,on="Key",how="inner")
# Out:
#   Key  Value1  Value2
# 0   A       1       4
# 1   B       2       5
